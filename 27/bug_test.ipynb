# %% [markdown]
# 27: Python function to remove all digits from a list of strings

# %%
# %%writefile bugged_remove_digits.py

import re
def remove(list):
  pattern = '[1-9]'
  list = [re.sub(pattern, '', i) for i in list]
  return list
# Out:
# Overwriting bugged_remove_digits.py

# %% [markdown]
# LLM TESTING

# %%
# %%writefile llm_test_remove_digits.py

import pytest
from bugged_remove_digits import remove

def test_basic_strings():
    # removes digits from mixed strings
    assert remove(["abc123", "45de6", "7f8g9"]) == ["abc", "de", "fg"]

def test_no_digits():
    # strings without digits should remain unchanged
    assert remove(["hello", "world"]) == ["hello", "world"]

def test_all_digits():
    # strings with only digits become empty
    assert remove(["123", "456", "7890"]) == ["", "", ""]

def test_empty_strings():
    # empty strings stay empty
    assert remove(["", "abc", ""]) == ["", "abc", ""]

def test_mixed_case_and_special_chars():
    # digits are removed, other chars remain
    assert remove(["A1b2C3!", "99hello!!", "Te5st"]) == ["AbC!", "hello!!", "Test"]

def test_strings_with_spaces():
    # spaces should be preserved and order of non-digit chars retained
    assert remove(["12 a3b 45", "6c d7"]) == [" ab ", "c d"]

def test_unicode_characters():
    # digits should be removed even when string has emojis or unicode letters
    assert remove(["hi123😊", "🚀4space5"]) == ["hi😊", "🚀space"]

def test_single_string_in_list():
    # works for single element list
    assert remove(["abc123xyz"]) == ["abcxyz"]

def test_empty_list():
    # empty input list should return empty list
    assert remove([]) == []

def test_numbers_embedded_with_letters():
    # removes digits from middle, start, and end
    assert remove(["1a2b3c4d", "9end", "start8", "mid7dle"]) == ["abcd", "end", "start", "middle"]
# Out:
# Overwriting llm_test_remove_digits.py

# %%
# !pytest -v llm_test_remove_digits.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.2, pytest-8.4.2, pluggy-1.6.0 -- C:\Python313\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default'
# rootdir: d:\IIIT HYD\SSD\Final project\HumanVsLLM\27
# plugins: anyio-4.9.0, hypothesis-6.147.0
# collecting ... collected 10 items
#
# llm_test_remove_digits.py::test_basic_strings PASSED                     [ 10%]
# llm_test_remove_digits.py::test_no_digits PASSED                         [ 20%]
# llm_test_remove_digits.py::test_all_digits FAILED                        [ 30%]
# llm_test_remove_digits.py::test_empty_strings PASSED                     [ 40%]
# llm_test_remove_digits.py::test_mixed_case_and_special_chars PASSED      [ 50%]
# llm_test_remove_digits.py::test_strings_with_spaces PASSED               [ 60%]
# llm_test_remove_digits.py::test_unicode_characters PASSED                [ 70%]
# llm_test_remove_digits.py::test_single_string_in_list PASSED             [ 80%]
# llm_test_remove_digits.py::test_empty_list PASSED                        [ 90%]
# llm_test_remove_digits.py::test_numbers_embedded_with_letters PASSED     [100%]
#
# ================================== FAILURES ===================================
# _______________________________ test_all_digits _______________________________
#
#     def test_all_digits():
#         # strings with only digits become empty
# >       assert remove(["123", "456", "7890"]) == ["", "", ""]
# E       AssertionError: assert ['', '', '0'] == ['', '', '']
# E
# E         At index 2 diff: '0' != ''
# E
# E         Full diff:
# E           [
# E               '',
# E               '',...
# E
# E         ...Full output truncated (4 lines hidden), use '-vv' to show
#
# llm_test_remove_digits.py:15: AssertionError
# =========================== short test summary info ===========================
# FAILED llm_test_remove_digits.py::test_all_digits - AssertionError: assert ['', '', '0'] == ['', '', '']
# ========================= 1 failed, 9 passed in 0.47s =========================

# %% [markdown]
# HUMAN TESTING

# %%
# %%writefile human_test_remove_digits.py
import pytest, string
from hypothesis import given, strategies as st
from bugged_remove_digits import remove

list_of_strings_strategy = st.lists(st.text())


@given(list_of_strings_strategy)
def test_same_length(input_list):

    """
    Property 1: The output list should have the same number of strings
    as the input list.
    """
    result = remove(input_list)
    assert len(result) == len(input_list)

@given(list_of_strings_strategy)
def test_contain_no_digits(input_list):
    """
    Property 2: The core requirement. No string in the output list
    should contain any digit.
    """
    result = remove(input_list)
    for s in result:
        for char in s:
            assert char not in string.digits, f"Found digit '{char}' in output string '{s}'"

@given(list_of_strings_strategy)
def test_is_idempotent(input_list):
    """
    Property 3: remove(remove(x)) == remove(x)
    """
    result1 = remove(input_list)
    result2 = remove(result1)
    assert result1 == result2

@given(list_of_strings_strategy)
def test_preserves_non_digit(input_list):
    """
    Property 4: Compares the function's output to a golden implementation.
    """
    expected_output = []
    for s in input_list:
        expected_s = "".join(char for char in s if not char.isdigit())
        expected_output.append(expected_s)
    
    actual_output = remove(input_list)

    assert actual_output == expected_output
# Out:
# Overwriting human_test_remove_digits.py

# %%
# !pytest -v human_test_remove_digits.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.2, pytest-8.4.2, pluggy-1.6.0 -- C:\Python313\python.exe
# cachedir: .pytest_cache
# hypothesis profile 'default'
# rootdir: d:\IIIT HYD\SSD\Final project\HumanVsLLM\27
# plugins: anyio-4.9.0, hypothesis-6.147.0
# collecting ... collected 4 items
#
# human_test_remove_digits.py::test_same_length PASSED                     [ 25%]
# human_test_remove_digits.py::test_contain_no_digits FAILED               [ 50%]
# human_test_remove_digits.py::test_is_idempotent PASSED                   [ 75%]
# human_test_remove_digits.py::test_preserves_non_digit FAILED             [100%]
#
# ================================== FAILURES ===================================
# ___________________________ test_contain_no_digits ____________________________
#
#     @given(list_of_strings_strategy)
# >   def test_contain_no_digits(input_list):
#                    ^^^
#
# human_test_remove_digits.py:19:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# input_list = ['0']
#
#     @given(list_of_strings_strategy)
#     def test_contain_no_digits(input_list):
#         """
#         Property 2: The core requirement. No string in the output list
#         should contain any digit.
#         """
#         result = remove(input_list)
#         for s in result:
#             for char in s:
# >               assert char not in string.digits, f"Found digit '{char}' in output string '{s}'"
# E               AssertionError: Found digit '0' in output string '0'
# E               assert '0' not in '0123456789'
# E
# E                 '0' is contained here:
# E                   0123456789
# E                 ? +
# E               Falsifying example: test_contain_no_digits(
# E                   input_list=['0'],
# E               )
#
# human_test_remove_digits.py:27: AssertionError
# __________________________ test_preserves_non_digit ___________________________
#
#     @given(list_of_strings_strategy)
# >   def test_preserves_non_digit(input_list):
#                    ^^^
#
# human_test_remove_digits.py:39:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# input_list = ['0']
#
#     @given(list_of_strings_strategy)
#     def test_preserves_non_digit(input_list):
#         """
#         Property 4: Compares the function's output to a golden implementation.
#         """
#         expected_output = []
#         for s in input_list:
#             expected_s = "".join(char for char in s if not char.isdigit())
#             expected_output.append(expected_s)
#
#         actual_output = remove(input_list)
#
# >       assert actual_output == expected_output
# E       AssertionError: assert ['0'] == ['']
# E
# E         At index 0 diff: '0' != ''
# E
# E         Full diff:
# E           [
# E         -     '',
# E         +     '0',
# E         ?      +
# E           ]
# E       Falsifying example: test_preserves_non_digit(
# E           input_list=['0'],
# E       )
#
# human_test_remove_digits.py:50: AssertionError
# =========================== short test summary info ===========================
# FAILED human_test_remove_digits.py::test_contain_no_digits - AssertionError: Found digit '0' in output string '0'
# FAILED human_test_remove_digits.py::test_preserves_non_digit - AssertionError: assert ['0'] == ['']
# ========================= 2 failed, 2 passed in 3.10s =========================
